# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
os.getcwd()

os.chdir(r'C:\Users\SohagMaitra\OneDrive - Amitech Solutions, Inc\Desktop\using-data-tha-sohagma\data')

os.getcwd()
# Out:
# 'C:\\Users\\SohagMaitra\\OneDrive - Amitech Solutions, Inc\\Desktop\\using-data-tha-sohagma\\data'

# %%
CaliforniaHospital_data = pd.read_table('CaliforniaHospitalData_Personnel.txt', sep='\t')
CaliforniaHospital_data
# Out:
#     HospitalID  Work_ID   LastName FirstName Gender  PositionID  \
# 0        35665   351131  Cherukuri    Dileep      M           4
# 1        12145   756481  Rodriguez      Jose      M           1
# 2        45771   756481  Rodriguez      Jose      M           1
# 3        43353   756481  Rodriguez      Jose      M           4
# 4        17718   811240    Charles   Kenneth      M           1
# ..         ...      ...        ...       ...    ...         ...
# 59       33283   704360      Frank    Vernon      M           1
# 60       33242   704360      Frank    Vernon      M           4
# 61       46342   768057     Tanner  Patricia      F           3
# 62       43437   768057     Tanner  Patricia      F           1
# 63       29823   768057     Tanner  Patricia      F           3
#
#                PositionTitle  Compensation  MaxTerm StartDate         Phone  \
# 0   Safety Inspection Member         23987        2  1/1/2019  405-564-5580
# ...

# %%
CaliforniaHospitalData_data = pd.read_csv('CaliforniaHospitalData.csv')
CaliforniaHospitalData_data
# Out:
#     HospitalID                                               Name         Zip  \
# 0        45740                                   Mammoth Hospital  93546-0660
# 1        12145                   Victor Valley Community Hospital       92392
# 2        25667                         Pioneers Memorial Hospital       92227
# 3        46996                       Ridgecrest Regional Hospital       93555
# 4        37393                         Barstow Community Hospital       92311
# ..         ...                                                ...         ...
# 56       32930                             Scripps Mercy Hospital       92103
# 57       31032   Long Beach Memorial & Miller Children's Hospital       90806
# 58       22460                        Stanford Hospital & Clinics       94305
# 59       33192  California Pacific Medical Center - Pacific Ca...       94115
# 60       38900                        Cedars-Sinai Medical Center       90048
#
# ...

# %%
display('CaliforniaHospital_data', 'CaliforniaHospitalData_data', "pd.merge(CaliforniaHospital_data, CaliforniaHospitalData_data, on='HospitalID')")
# Out:
# 'CaliforniaHospital_data'
# 'CaliforniaHospitalData_data'
# "pd.merge(CaliforniaHospital_data, CaliforniaHospitalData_data, on='HospitalID')"

# %%
combinefile = pd.merge(CaliforniaHospital_data, CaliforniaHospitalData_data)
combinefile
# Out:
#     HospitalID  Work_ID   LastName FirstName Gender  PositionID  \
# 0        12145   756481  Rodriguez      Jose      M           1
# 1        45771   756481  Rodriguez      Jose      M           1
# 2        43353   756481  Rodriguez      Jose      M           4
# 3        17718   811240    Charles   Kenneth      M           1
# 4        17736   811240    Charles   Kenneth      M           3
# ..         ...      ...        ...       ...    ...         ...
# 56       33283   704360      Frank    Vernon      M           1
# 57       33242   704360      Frank    Vernon      M           4
# 58       46342   768057     Tanner  Patricia      F           3
# 59       43437   768057     Tanner  Patricia      F           1
# 60       29823   768057     Tanner  Patricia      F           3
#
#                PositionTitle  Compensation  MaxTerm StartDate  ...  \
# 0    Regional Representative         46978        4  1/1/2009  ...
# ...

# %%
combinefile.drop (['Work_ID', 'PositionID', 'Website'], axis=1)
# Out:
#     HospitalID   LastName FirstName Gender             PositionTitle  \
# 0        12145  Rodriguez      Jose      M   Regional Representative
# 1        45771  Rodriguez      Jose      M   Regional Representative
# 2        43353  Rodriguez      Jose      M  Safety Inspection Member
# 3        17718    Charles   Kenneth      M   Regional Representative
# 4        17736    Charles   Kenneth      M           Acting Director
# ..         ...        ...       ...    ...                       ...
# 56       33283      Frank    Vernon      M   Regional Representative
# 57       33242      Frank    Vernon      M  Safety Inspection Member
# 58       46342     Tanner  Patricia      F           Acting Director
# 59       43437     Tanner  Patricia      F   Regional Representative
# 60       29823     Tanner  Patricia      F           Acting Director
#
#     Compensation  MaxTerm StartDate         Phone  \
# 0          46978        4  1/1/2009  405-744-2238
# ...

# %%
combinefile[(combinefile.Teaching=='Small/Rural')&(combinefile.AvlBeds>=15)]
# Out:
#     HospitalID  Work_ID   LastName FirstName Gender  PositionID  \
# 0        12145   756481  Rodriguez      Jose      M           1
# 1        45771   756481  Rodriguez      Jose      M           1
# 3        17718   811240    Charles   Kenneth      M           1
# 4        17736   811240    Charles   Kenneth      M           3
# 5        33207   811240    Charles   Kenneth      M           2
# 6        46985   548312      Smith     Frank      M           1
# 7        28283   548312      Smith     Frank      M           3
# 9        13722   625519      Brown  Marietta      F           4
# 10       11875   380668      Smith      Mary      F           1
# 12       46838   229849    Milgrom  Patricia      F           1
# 13       13738   229849    Milgrom  Patricia      F           4
# 14       38802   310431       Dong   HongWei      F           1
# 16       46348   664583     Paanua   Kaaluai      M           1
# 18       37043   664583     Paanua   Kaaluai      M           2
# ...

# %%
combinefile[(combinefile.OperInc > 0)]
# Out:
#     HospitalID  Work_ID  LastName FirstName Gender  PositionID  \
# 3        17718   811240   Charles   Kenneth      M           1
# 4        17736   811240   Charles   Kenneth      M           3
# 5        33207   811240   Charles   Kenneth      M           2
# 6        46985   548312     Smith     Frank      M           1
# 7        28283   548312     Smith     Frank      M           3
# 8        35512   625519     Brown  Marietta      F           1
# 9        13722   625519     Brown  Marietta      F           4
# 11       22460   380668     Smith      Mary      F           4
# 13       13738   229849   Milgrom  Patricia      F           4
# 14       38802   310431      Dong   HongWei      F           1
# 15       31032   310431      Dong   HongWei      F           4
# 16       46348   664583    Paanua   Kaaluai      M           1
# 17       38900   664583    Paanua   Kaaluai      M           1
# 18       37043   664583    Paanua   Kaaluai      M           2
# ...

# %%
combinefile.to_csv(r'C:\Users\SohagMaitra\OneDrive - Amitech Solutions, Inc\Documents\OSU\MSIS 5193\Week 4\hospital_data_new.txt', sep ='\t')

# %%
new_df = pd.read_table(r'C:\Users\SohagMaitra\OneDrive - Amitech Solutions, Inc\Documents\OSU\MSIS 5193\Week 4\hospital_data_new.txt', sep ='\t')

# %%
new_df.rename(columns={'NoFTE':'FullTimeCount'}, inplace=True)
new_df.rename(columns={'NetPatRev':'NetPatientRevenue'}, inplace=True)
new_df.rename(columns={'InOperExp':'InpatientOperExp'}, inplace=True)
new_df.rename(columns={'OutOperExp':'OutpatientOperExp'}, inplace=True)
new_df.rename(columns={'OperRev':'Operating_Revenue'}, inplace=True)
new_df.rename(columns={'OperInc':'Operating_Income'}, inplace=True)

# %%
new_df.columns
# Out:
# Index(['Unnamed: 0', 'HospitalID', 'Work_ID', 'LastName', 'FirstName',
#        'Gender', 'PositionID', 'PositionTitle', 'Compensation', 'MaxTerm',
#        'StartDate', 'Phone', 'Email', 'Name', 'Zip', 'Website', 'TypeControl',
#        'Teaching', 'DonorType', 'FullTimeCount', 'NetPatientRevenue',
#        'InpatientOperExp', 'OutpatientOperExp', 'Operating_Revenue',
#        'Operating_Income', 'AvlBeds'],
#       dtype='object')

# %%
newrows = [{'Name':'Arrowhead Regional Medical Center', 'LastName':'Maitra', 'FirstName':'Sohag','StartDate':9/14/2021,'PositionTitle': 'Regional Representative','Compensation':46978,
'MaxTerm':4},
           {'Name':'Alameda Hospital', 'LastName':'Maitra', 'FirstName':'Sohag','StartDate':9/14/2021,'PositionTitle': 'Regional Representative','Compensation':46978,
'MaxTerm':4}]

# %%
new_merge = new_df.append(newrows, ignore_index=True)

# %%
len(new_merge.index.values)

len(new_merge.index.values)
# Out:
# 63

# %%
new_merge.columns
# Out:
# Index(['Unnamed: 0', 'HospitalID', 'Work_ID', 'LastName', 'FirstName',
#        'Gender', 'PositionID', 'PositionTitle', 'Compensation', 'MaxTerm',
#        'StartDate', 'Phone', 'Email', 'Name', 'Zip', 'Website', 'TypeControl',
#        'Teaching', 'DonorType', 'FullTimeCount', 'NetPatientRevenue',
#        'InpatientOperExp', 'OutpatientOperExp', 'Operating_Revenue',
#        'Operating_Income', 'AvlBeds'],
#       dtype='object')

# %%
new_merge
# Out:
#     Unnamed: 0  HospitalID   Work_ID   LastName FirstName Gender  PositionID  \
# 0          0.0     12145.0  756481.0  Rodriguez      Jose      M         1.0
# 1          1.0     45771.0  756481.0  Rodriguez      Jose      M         1.0
# 2          2.0     43353.0  756481.0  Rodriguez      Jose      M         4.0
# 3          3.0     17718.0  811240.0    Charles   Kenneth      M         1.0
# 4          4.0     17736.0  811240.0    Charles   Kenneth      M         3.0
# ..         ...         ...       ...        ...       ...    ...         ...
# 58        58.0     46342.0  768057.0     Tanner  Patricia      F         3.0
# 59        59.0     43437.0  768057.0     Tanner  Patricia      F         1.0
# 60        60.0     29823.0  768057.0     Tanner  Patricia      F         3.0
# 61         NaN         NaN       NaN     Maitra     Sohag    NaN         NaN
# 62         NaN         NaN       NaN     Maitra     Sohag    NaN         NaN
#
# ...

# %%
new_merge = pd.read_table(r'C:\Users\SohagMaitra\OneDrive - Amitech Solutions, Inc\Documents\OSU\MSIS 5193\Week 4\hospital_data_new.txt')

new_merge.dtypes
# Out:
# Unnamed: 0         int64
# HospitalID         int64
# Work_ID            int64
# LastName          object
# FirstName         object
# Gender            object
# PositionID         int64
# PositionTitle     object
# Compensation       int64
# MaxTerm            int64
# StartDate         object
# Phone             object
# Email             object
# Name              object
# Zip               object
# Website           object
# TypeControl       object
# Teaching          object
# DonorType         object
# NoFTE            float64
# NetPatRev        float64
# InOperExp        float64
# OutOperExp       float64
# OperRev            int64
# OperInc            int64
# AvlBeds            int64
# dtype: object

# %%
new_merge['StartDate'] = pd.to_datetime(new_merge['StartDate'])

new_merge.StartDate.head()
# Out:
# 0   2009-01-01
# 1   2011-01-01
# 2   2011-01-01
# 3   2009-01-01
# 4   2006-01-01
# Name: StartDate, dtype: datetime64[ns]

# %%
new_merge[(new_merge.TypeControl=='Non Profit')&(new_merge.NoFTE>250)&(new_merge.NetPatRev<109000)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, HospitalID, Work_ID, LastName, FirstName, Gender, PositionID, PositionTitle, Compensation, MaxTerm, StartDate, Phone, Email, Name, Zip, Website, TypeControl, Teaching, DonorType, NoFTE, NetPatRev, InOperExp, OutOperExp, OperRev, OperInc, AvlBeds]
# Index: []
#
# [0 rows x 26 columns]

# %%
new_merge[(new_merge.PositionTitle=='Regional Representative')&(new_merge.OperInc>100000)]
# Out:
#     Unnamed: 0  HospitalID  Work_ID  LastName FirstName Gender  PositionID  \
# 3            3       17718   811240   Charles   Kenneth      M           1
# 8            8       35512   625519     Brown  Marietta      F           1
# 14          14       38802   310431      Dong   HongWei      F           1
# 16          16       46348   664583    Paanua   Kaaluai      M           1
# 17          17       38900   664583    Paanua   Kaaluai      M           1
# 20          20       33192   308150   Fourier     Craig      M           1
# 31          31       39076   304224      Wood     Emily      F           1
# 35          35       20266   231581     Adams     Sandy      F           1
# 41          41       19868   318165   Coulter     Tracy      F           1
# 47          47       20277   398103  Johanson     Sandy      F           1
# 51          51       32930   411280     Manin     Emily      F           1
# ...

# %%
new_merge2 = new_merge.append(newrows, ignore_index=True)

# %%
new_merge2.to_csv(r'C:\Users\SohagMaitra\OneDrive - Amitech Solutions, Inc\Documents\OSU\MSIS 5193\Week 4\hospital_data_new_file.txt', sep ='\t')
